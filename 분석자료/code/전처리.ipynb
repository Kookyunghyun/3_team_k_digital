# %%
import pandas as pd

encode = "cp949"
df = pd.read_csv("소비자물가지수.csv", encoding=encode)
df
# Out:
#    시도별(1)   시도별(2)    2002    2003    2004    2005    2006    2007    2008
# 0      전국       소계  67.534  69.908  72.418  74.413  76.081  78.010  81.656  \
# 1      전국    서울특별시  66.640  69.180  71.874  73.755  75.279  77.252  80.466
# 2      전국    부산광역시  66.963  69.366  71.462  73.441  75.063  76.906  80.547
# 3      전국    대구광역시  67.653  69.886  71.945  73.796  75.481  77.264  80.979
# 4      전국    인천광역시  68.067  70.250  72.692  74.541  76.324  78.100  81.945
# 5      전국    광주광역시  67.756  69.985  72.948  75.166  76.851  78.855  82.595
# 6      전국    대전광역시  68.773  70.941  73.648  75.800  77.733  79.641  83.393
# 7      전국    울산광역시  67.623  69.927  72.596  74.823  76.875  79.064  83.180
# 8      전국  세종특별자치시       -       -       -       -       -       -       -
# 9      전국      경기도  67.577  69.868  72.280  74.284  76.097  78.004  81.767
# 10     전국      강원도  67.715  70.049  72.745  75.324  77.038  78.833  83.026
# ...

# %%
df = df.loc[df['시도별(2)']== '충청남도']

# %%
df = df.drop("2022",axis=1)

# %%
df.to_csv("소비자물가지수2.csv")

# %%
import pandas as pd

encode = "cp949"
df = pd.read_csv("시도별.csv", encoding=encode)
df
# Out:
#         시도별        2002     2002.1    2002.2    2002.3        2003     2003.1
# 0       시도별  1인당 지역내총생산  1인당 지역총소득  1인당 개인소득  1인당 민간소비  1인당 지역내총생산  1인당 지역총소득  \
# 1        전국       16505      16444      9820      9263       17609      17548
# 2     서울특별시       19847      21804     11463     10728       21134      23579
# 3     부산광역시       11901      13090      9330      8960       13122      13755
# 4     대구광역시       10694      12483      9246      9140       11313      12851
# 5     인천광역시       14956      13481      8700      8622       15778      14614
# 6     광주광역시       11700      12501      9011      9006       12068      13047
# 7     대전광역시       12809      14491      9288      9008       13741      15826
# 8     울산광역시       34404      29386     11896      9084       34290      29152
# 9   세종특별자치시           -          -         -         -           -          -
# 10      경기도       15430      16720     10122      9316       16165      17493
# ...

# %%
df = df.loc[(df['시도별'] == '충청남도')|(df['시도별'] == '시도별')]

# %%
df
# Out:
#      시도별        2002     2002.1    2002.2    2002.3        2003     2003.1
# 0    시도별  1인당 지역내총생산  1인당 지역총소득  1인당 개인소득  1인당 민간소비  1인당 지역내총생산  1인당 지역총소득  \
# 13  충청남도       20656      15557      8929      8690       23280      17564
#
#       2003.2    2003.3        2004  ...    2019.2    2019.3        2020
# 0   1인당 개인소득  1인당 민간소비  1인당 지역내총생산  ...  1인당 개인소득  1인당 민간소비  1인당 지역내총생산  \
# 13      9454      8915       25934  ...     19216     16123       53078
#
#        2020.1    2020.2    2020.3     2021 p)  2021 p).1 2021 p).2 2021 p).3
# 0   1인당 지역총소득  1인당 개인소득  1인당 민간소비  1인당 지역내총생산  1인당 지역총소득  1인당 개인소득  1인당 민간소비
# 13      42073     20393     15426       57241      45544     21262     16319
#
# [2 rows x 81 columns]

# %%
extracted_columns = df.loc[:, df.eq('1인당 개인소득').any()]

# %%
lst = [x for x in range(2002, 2022)]
lst
# Out:
# [2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021]

# %%
extracted_columns.columns = lst

# %%
df = extracted_columns

# %%
df
# Out:
#         2002      2003      2004      2005      2006      2007      2008
# 0   1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  \
# 13      8929      9454     10075     10417     10994     11365     12006
#
#         2009      2010      2011      2012      2013      2014      2015
# 0   1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  \
# 13     12660     13326     13376     13948     14892     15509     16703
#
#         2016      2017      2018      2019      2020      2021
# 0   1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득
# 13     16952     17788     18458     19216     20393     21262

# %%
df.insert(0,'시도별', ['시도별', '충청남도'])

# %%
df
# Out:
#      시도별      2002      2003      2004      2005      2006      2007
# 0    시도별  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  \
# 13  충청남도      8929      9454     10075     10417     10994     11365
#
#         2008      2009      2010  ...      2012      2013      2014      2015
# 0   1인당 개인소득  1인당 개인소득  1인당 개인소득  ...  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  \
# 13     12006     12660     13326  ...     13948     14892     15509     16703
#
#         2016      2017      2018      2019      2020      2021
# 0   1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득
# 13     16952     17788     18458     19216     20393     21262
#
# [2 rows x 21 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#     시도별      2002      2003      2004      2005      2006      2007      2008
# 0   시도별  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  \
# 1  충청남도      8929      9454     10075     10417     10994     11365     12006
#
#        2009      2010  ...      2012      2013      2014      2015      2016
# 0  1인당 개인소득  1인당 개인소득  ...  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  \
# 1     12660     13326  ...     13948     14892     15509     16703     16952
#
#        2017      2018      2019      2020      2021
# 0  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득  1인당 개인소득
# 1     17788     18458     19216     20393     21262
#
# [2 rows x 21 columns]

# %%
df.to_csv('개인소득.csv')

# %%
df = pd.read_csv('소비자물가지수2.csv')
df
# Out:
#    Unnamed: 0 시도별(1) 시도별(2)    2002    2003    2004    2005    2006   2007
# 0          12     전국   충청남도  67.795  70.279  73.019  75.363  77.291  79.22  \
#
#     2008  ...    2012    2013    2014    2015    2016    2017    2018    2019
# 0  83.12  ...  93.753  94.867  95.309  95.515  96.171  98.036  99.437  99.343  \
#
#     2020    2021
# 0  100.0  102.77
#
# [1 rows x 23 columns]

# %%
df = df.drop("Unnamed: 0",axis=1)

# %%
df = df.drop("시도별(1)",axis=1)

# %%
df
# Out:
#   시도별(2)    2002    2003    2004    2005    2006   2007   2008    2009
# 0   충청남도  67.795  70.279  73.019  75.363  77.291  79.22  83.12  85.387  \
#
#      2010  ...    2012    2013    2014    2015    2016    2017    2018
# 0  87.954  ...  93.753  94.867  95.309  95.515  96.171  98.036  99.437  \
#
#      2019   2020    2021
# 0  99.343  100.0  102.77
#
# [1 rows x 21 columns]

# %%
df.columns.values[0] = '시도별'

# %%
df.to_csv('소비자물가지수2.csv')
